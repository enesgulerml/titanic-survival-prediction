# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.data_processing import load_data
from src.config import TRAIN_DATA_PATH, TARGET_VARIABLE

# %%
data = load_data(TRAIN_DATA_PATH)
# Out:
# Data successfully loaded from C:\Users\jenes\PycharmProjects\titanic-survival-prediction\data\raw\train.csv.

# %%
sns.countplot(x=TARGET_VARIABLE, data=data)
plt.title("Survival Distribution")
plt.show()

# %%
sns.histplot(data=data, x='Age', hue=TARGET_VARIABLE, kde=True)
plt.show()
